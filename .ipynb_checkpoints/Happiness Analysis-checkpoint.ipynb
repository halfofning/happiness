# %% [markdown]
# # World Happiness Analysis

# %% [markdown]
# ## Context & Content
# The happiness scores and rankings are based on answers to the main life evaluation question asked in the poll. This question asks respondents to think of a ladder with the *best possible life for them being a 10* and the *worst possible life being a 0* and to rate their own current lives on that scale.
#
# The columns following the happiness score estimate the extent to which each of **six factors – economic production, social support, life expectancy, freedom, absence of corruption, and generosity** – contribute to making life evaluations higher in each country than they are in Dystopia, a hypothetical country that has values equal to the world’s lowest national averages for each of the six factors. They have no impact on the total score reported for each country, but they do explain why some countries rank higher than others.
#
# ## Problem Statement
# Knowing from the sample dataset (2016) listing the happiness scores of representatives in each country and the factors that contribute to these scores, how accurate can we predict the happiness scores of each country in 2017?

# %%
# Importing libraries for data analysis
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error
from math import sqrt

# Importing libraries for visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Importing the dataset
# 2016
dataset2016 = pd.read_csv('dataset/2016.csv')
X_2016 = dataset2016.iloc[:, :-1].values
y_2016 = dataset2016.iloc[:, 8].values

# %%
# Encoding categorical data
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder = LabelEncoder()
X_2016[:, 0] = labelencoder.fit_transform(X_2016[:, 0])
onehotencoder = OneHotEncoder(categorical_features = [0])
X_2016 = onehotencoder.fit_transform(X_2016).toarray()

# Avoiding the Dummy Variable Trap
X_2016 = X_2016[:, 1:]

# %%
# Splitting the dataset into the Training set and Test set
X_2016_train, X_2016_test, y_2016_train, y_2016_test = train_test_split(X_2016, y_2016, test_size = 0.2, random_state = 0)

# %% [markdown]
# We will make use of 3 different methods to create regression models, to find out the most accurate model to act as the final model for the prediction of happiness score for the year 2017.
#
# #### Regression Models
# - Multiple Linear Regression
# - Decision Tree
# - Artificial Neural Network

# %% [markdown]
# ### Multiple Linear Regression

# %%
# MODEL 1: Making use of Multiple Linear Regression
#Fitting Multiple Linear Regression to the Training set 
from sklearn.linear_model import LinearRegression
ml_regressor = LinearRegression()
ml_regressor.fit(X_2016_train, y_2016_train)

# Predicting the Test set results
y_2016_pred_mlr = ml_regressor.predict(X_2016_test)

# Building the optimal model using Backward Elimination
import statsmodels.formula.api as sm
X_2016 = np.append(arr = np.ones((155, 1)).astype(int), values = X_2016, axis = 1)
print(X_2016)
X_opt = X_2016[:,:]

#Step 2
ml_regressor_OLS = sm.OLS(endog = y_2016, exog = X_opt).fit()

#Step 3 
X_opt = X_2016[:,:] #removed state
ml_regressor_OLS = sm.OLS(endog = y_2016, exog = X_opt).fit()
ml_regressor_OLS.summary()
# Out:
# [[1.      1.      1.      ... 0.07112 0.31268 2.14558]
#  [1.      1.      1.      ... 0.05301 0.1684  1.92816]
#  [1.      1.      1.      ... 0.16157 0.07044 3.40904]
#  ...
#  [1.      1.      1.      ... 0.05892 0.09821 1.97295]
#  [1.      1.      1.      ... 0.11479 0.17866 2.58991]
#  [1.      1.      1.      ... 0.08582 0.18503 2.4427 ]]
# C:\Users\esthe\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1549: RuntimeWarning: divide by zero encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# C:\Users\esthe\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1550: RuntimeWarning: invalid value encountered in double_scalars
#   * (1 - self.rsquared))
# C:\Users\esthe\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1558: RuntimeWarning: divide by zero encountered in double_scalars
#   return self.ssr/self.df_resid
# C:\Users\esthe\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1510: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                     0.000
# Date:                Sat, 23 Feb 2019   Prob (F-statistic):                nan
# Time:                        03:41:45   Log-Likelihood:                 4550.6
# No. Observations:                 155   AIC:                            -8791.
# Df Residuals:                       0   BIC:                            -8319.
# Df Model:                         154
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0132        inf          0        nan         nan         nan
# x1             0.0132        inf          0        nan         nan         nan
# x2             0.0132        inf          0        nan         nan         nan
# x3             0.0132        inf          0        nan         nan         nan
# x4             0.0132        inf          0        nan         nan         nan
# x5             0.0132        inf          0        nan         nan         nan
# x6             0.0132        inf          0        nan         nan         nan
# x7             0.0132        inf          0        nan         nan         nan
# x8             0.0132        inf          0        nan         nan         nan
# x9             0.0132        inf          0        nan         nan         nan
# x10            0.0132        inf          0        nan         nan         nan
# x11           -0.0242        inf         -0        nan         nan         nan
# x12           -0.0093        inf         -0        nan         nan         nan
# x13           -0.0927        inf         -0        nan         nan         nan
# x14           -0.0215        inf         -0        nan         nan         nan
# x15           -0.0631        inf         -0        nan         nan         nan
# x16            0.1212        inf          0        nan         nan         nan
# x17            0.0575        inf          0        nan         nan         nan
# x18           -0.0344        inf         -0        nan         nan         nan
# x19            0.0109        inf          0        nan         nan         nan
# x20            0.0280        inf          0        nan         nan         nan
# x21           -0.0171        inf         -0        nan         nan         nan
# x22            0.0493        inf          0        nan         nan         nan
# x23            0.0221        inf          0        nan         nan         nan
# x24           -0.0120        inf         -0        nan         nan         nan
# x25            0.0605        inf          0        nan         nan         nan
# x26            0.0064        inf          0        nan         nan         nan
# x27           -0.0113        inf         -0        nan         nan         nan
# x28           -0.0798        inf         -0        nan         nan         nan
# x29            0.0121        inf          0        nan         nan         nan
# x30           -0.0892        inf         -0        nan         nan         nan
# x31           -0.0049        inf         -0        nan         nan         nan
# x32           -0.0174        inf         -0        nan         nan         nan
# x33            0.0301        inf          0        nan         nan         nan
# x34           -0.0197        inf         -0        nan         nan         nan
# x35            0.1149        inf          0        nan         nan         nan
# x36           -0.0565        inf         -0        nan         nan         nan
# x37            0.0407        inf          0        nan         nan         nan
# x38           -0.0548        inf         -0        nan         nan         nan
# x39           -0.0150        inf         -0        nan         nan         nan
# x40            0.0054        inf          0        nan         nan         nan
# x41           -0.0421        inf         -0        nan         nan         nan
# x42           -0.0029        inf         -0        nan         nan         nan
# x43            0.0359        inf          0        nan         nan         nan
# x44           -0.0280        inf         -0        nan         nan         nan
# x45           -0.0076        inf         -0        nan         nan         nan
# x46           -0.0373        inf         -0        nan         nan         nan
# x47            0.1267        inf          0        nan         nan         nan
# x48           -0.0152        inf         -0        nan         nan         nan
# x49            0.0059        inf          0        nan         nan         nan
# x50           -0.0422        inf         -0        nan         nan         nan
# x51           -0.0092        inf         -0        nan         nan         nan
# x52           -0.0352        inf         -0        nan         nan         nan
# x53            0.0566        inf          0        nan         nan         nan
# x54            0.0972        inf          0        nan         nan         nan
# x55           -0.0018        inf         -0        nan         nan         nan
# x56           -0.0947        inf         -0        nan         nan         nan
# x57            0.0257        inf          0        nan         nan         nan
# x58            0.0660        inf          0        nan         nan         nan
# x59           -0.0278        inf         -0        nan         nan         nan
# x60           -0.0877        inf         -0        nan         nan         nan
# x61            0.0351        inf          0        nan         nan         nan
# x62            0.0207        inf          0        nan         nan         nan
# x63            0.0661        inf          0        nan         nan         nan
# x64           -0.0113        inf         -0        nan         nan         nan
# x65            0.0696        inf          0        nan         nan         nan
# x66           -0.0742        inf         -0        nan         nan         nan
# x67            0.0826        inf          0        nan         nan         nan
# x68            0.0058        inf          0        nan         nan         nan
# x69            0.0347        inf          0        nan         nan         nan
# x70            0.0117        inf          0        nan         nan         nan
# x71           -0.0264        inf         -0        nan         nan         nan
# x72            0.0925        inf          0        nan         nan         nan
# x73            0.0379        inf          0        nan         nan         nan
# x74           -0.0486        inf         -0        nan         nan         nan
# x75           -0.0212        inf         -0        nan         nan         nan
# x76           -0.0156        inf         -0        nan         nan         nan
# x77           -0.0138        inf         -0        nan         nan         nan
# x78           -0.0198        inf         -0        nan         nan         nan
# x79           -0.0282        inf         -0        nan         nan         nan
# x80            0.0191        inf          0        nan         nan         nan
# x81           -0.0005        inf         -0        nan         nan         nan
# x82           -0.0072        inf         -0        nan         nan         nan
# x83            0.0305        inf          0        nan         nan         nan
# x84            0.0794        inf          0        nan         nan         nan
# x85           -0.0363        inf         -0        nan         nan         nan
# x86           -0.0219        inf         -0        nan         nan         nan
# x87           -0.0077        inf         -0        nan         nan         nan
# x88           -0.0255        inf         -0        nan         nan         nan
# x89           -0.0905        inf         -0        nan         nan         nan
# x90            0.0619        inf          0        nan         nan         nan
# x91           -0.0177        inf         -0        nan         nan         nan
# x92           -0.0096        inf         -0        nan         nan         nan
# x93            0.0512        inf          0        nan         nan         nan
# x94            0.0274        inf          0        nan         nan         nan
# x95           -0.0158        inf         -0        nan         nan         nan
# x96            0.0907        inf          0        nan         nan         nan
# x97           -0.0161        inf         -0        nan         nan         nan
# x98            0.0177        inf          0        nan         nan         nan
# x99            0.0270        inf          0        nan         nan         nan
# x100          -0.0077        inf         -0        nan         nan         nan
# x101          -0.0234        inf         -0        nan         nan         nan
# x102          -0.0232        inf         -0        nan         nan         nan
# x103          -0.0281        inf         -0        nan         nan         nan
# x104           0.1562        inf          0        nan         nan         nan
# x105          -0.0556        inf         -0        nan         nan         nan
# x106           0.0413        inf          0        nan         nan         nan
# x107           0.1151        inf          0        nan         nan         nan
# x108           0.1495        inf          0        nan         nan         nan
# x109           0.0601        inf          0        nan         nan         nan
# x110           0.0195        inf          0        nan         nan         nan
# x111          -0.0428        inf         -0        nan         nan         nan
# x112           0.0212        inf          0        nan         nan         nan
# x113           0.1023        inf          0        nan         nan         nan
# x114           0.0421        inf          0        nan         nan         nan
# x115          -0.0248        inf         -0        nan         nan         nan
# x116           0.0134        inf          0        nan         nan         nan
# x117          -0.0078        inf         -0        nan         nan         nan
# x118          -0.0235        inf         -0        nan         nan         nan
# x119           0.0015        inf          0        nan         nan         nan
# x120          -0.0424        inf         -0        nan         nan         nan
# x121          -0.0661        inf         -0        nan         nan         nan
# x122           0.0145        inf          0        nan         nan         nan
# x123           0.0836        inf          0        nan         nan         nan
# x124          -0.0487        inf         -0        nan         nan         nan
# x125          -0.0795        inf         -0        nan         nan         nan
# x126           0.0912        inf          0        nan         nan         nan
# x127           0.0160        inf          0        nan         nan         nan
# x128          -0.0110        inf         -0        nan         nan         nan
# x129          -0.0348        inf         -0        nan         nan         nan
# x130          -0.0098        inf         -0        nan         nan         nan
# x131           0.1124        inf          0        nan         nan         nan
# x132          -0.0546        inf         -0        nan         nan         nan
# x133          -0.0208        inf         -0        nan         nan         nan
# x134           0.1217        inf          0        nan         nan         nan
# x135          -0.0790        inf         -0        nan         nan         nan
# x136          -0.0166        inf         -0        nan         nan         nan
# x137           0.0098        inf          0        nan         nan         nan
# x138          -0.0242        inf         -0        nan         nan         nan
# x139           0.0216        inf          0        nan         nan         nan
# x140          -0.0489        inf         -0        nan         nan         nan
# x141           0.1210        inf          0        nan         nan         nan
# x142           0.1010        inf          0        nan         nan         nan
# x143           0.0484        inf          0        nan         nan         nan
# x144          -0.0074        inf         -0        nan         nan         nan
# x145           0.0346        inf          0        nan         nan         nan
# x146          -0.0184        inf         -0        nan         nan         nan
# x147           0.0674        inf          0        nan         nan         nan
# x148           0.0027        inf          0        nan         nan         nan
# x149          -0.0188        inf         -0        nan         nan         nan
# x150          -0.0432        inf         -0        nan         nan         nan
# x151          -0.0533        inf         -0        nan         nan         nan
# x152           0.0202        inf          0        nan         nan         nan
# x153          -0.0260        inf         -0        nan         nan         nan
# x154          -0.0650        inf         -0        nan         nan         nan
# x155           0.0632        inf          0        nan         nan         nan
# x156           0.0998        inf          0        nan         nan         nan
# x157           0.0534        inf          0        nan         nan         nan
# x158           0.0294        inf          0        nan         nan         nan
# x159           0.0790        inf          0        nan         nan         nan
# x160          -0.0554        inf         -0        nan         nan         nan
# x161           0.0226        inf          0        nan         nan         nan
# x162          -0.0584        inf         -0        nan         nan         nan
# x163          -0.0114        inf         -0        nan         nan         nan
# x164          -0.0263        inf         -0        nan         nan         nan
# x165           1.0421        inf          0        nan         nan         nan
# x166           1.0219        inf          0        nan         nan         nan
# x167           0.9220        inf          0        nan         nan         nan
# x168           0.9446        inf          0        nan         nan         nan
# x169           0.7388        inf          0        nan         nan         nan
# x170           0.7702        inf          0        nan         nan         nan
# x171           0.9765        inf          0        nan         nan         nan
# ==============================================================================
# Omnibus:                       20.791   Durbin-Watson:                   0.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.592
# Skew:                          -0.700   Prob(JB):                     8.37e-08
# Kurtosis:                       4.756   Cond. No.                         231.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# """

# %% [markdown]
# **Multiple Linear Regression**: Compute the root mean squared error (% accuracy) between the predicted value and the actual value.

# %%
# MODEL 1: Making use of Multiple Linear Regression (RMSE)
# rms = sqrt(mean_squared_error(y_actual, y_pred))

# %% [markdown]
# ### Decision Tree

# %%
# MODEL 2: Making use of Decision Trees

# %% [markdown]
# **Decision Tree**: Compute the root mean squared error (% accuracy) between the predicted value and the actual value.

# %%
# MODEL 2: Making use of Decision Trees (RMSE)
# rms = sqrt(mean_squared_error(y_actual, y_predicted))

# %% [markdown]
# ### Artificial Neural Networks

# %%
# MODEL 3: Making use of Artificial Neural Networks

# %% [markdown]
# **Artificial Neural Networks**: Compute the root mean squared error (% accuracy) between the predicted value and the actual value.

# %%
# MODEL 3: Making use of Artificial Neural Networks (RMSE)
# rms = sqrt(mean_squared_error(y_actual, y_predicted))

# %% [markdown]
# ## Conclusion
# The most accurate model that can predict the happiness scores is the (____) model.
#
# The final model will thus be this model, and will be used to predict the happiness scores for the 2017 dataset.

# %% [markdown]
# ## Predicting 2017's Happiness Scores

# %%
# 2017
dataset2017 = pd.read_csv('dataset/2017.csv')
X_2017 = dataset2017.iloc[:, :-1].values
y_2017 = dataset2017.iloc[:, 8].values

# Encoding categorical data
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder = LabelEncoder()
X_2017[:, 0] = labelencoder.fit_transform(X_2017[:, 0])
onehotencoder = OneHotEncoder(categorical_features = [0])
X_2017 = onehotencoder.fit_transform(X_2017).toarray()

# Avoiding the Dummy Variable Trap
X_2017 = X_2017[:, 1:]

# %%
# Predicting the 2017 dataset results using the model
# y_pred = regressor.predict(X_2016_test)
